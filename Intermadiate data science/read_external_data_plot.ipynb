# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df=pd.read_csv("/home/halil/Belgeler/Kodlama calismalari/py/Patika/Intermadiate data science/BTC-USD.csv")
df["Date"]=pd.to_datetime(df["Date"])
df.set_index("Date", inplace=True)

# %%
df.loc["2017-08-12","Close"]
# Out:
# 3884.709961

# %% [markdown]
# ### Bunları aynı zamanda **read_csv** komutu içerisinde de en başında yapabilirdik.

# %%
df=pd.read_csv(
    "/home/halil/Belgeler/Kodlama calismalari/py/Patika/Intermadiate data science/BTC-USD.csv",
    index_col=0,
    parse_dates=True
)

# %%
df.head()
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2014-09-17  465.864014  468.174011  452.421997  457.334015  457.334015
# 2014-09-18  456.859985  456.859985  413.104004  424.440002  424.440002
# 2014-09-19  424.102997  427.834991  384.532013  394.795990  394.795990
# 2014-09-20  394.673004  423.295990  389.882996  408.903992  408.903992
# 2014-09-21  408.084991  412.425995  393.181000  398.821014  398.821014
#
#               Volume
# Date
# 2014-09-17  21056800
# 2014-09-18  34483200
# 2014-09-19  37919700
# 2014-09-20  36863600
# 2014-09-21  26580100

# %%
#df.price=df["Close"]
#df.price.values
plt.plot(df.index,df["Open"])
