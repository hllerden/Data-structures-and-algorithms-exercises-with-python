# %%
import numpy as np
import pandas as pd
import math
import matplotlib as plt
from pandas.api.types import is_string_dtype,is_numeric_dtype

# %matplotlib inline
# Out:
# Failed to start the Kernel.
#
# Jupyter server crashed. Unable to connect.
#
# Error code from Jupyter: 1
#
# /home/halil/.local/lib/python3.12/site-packages/traitlets/traitlets.py:2548: FutureWarning: Supporting extra quotes around strings is deprecated in traitlets 5.0. You can use '/home/halil/Belgeler/Kodlama calismalari/py/Patika' instead of '"/home/halil/Belgeler/Kodlama calismalari/py/Patika"' if you require traitlets >=5.
#
#   warn(
#
#
#
# [I 15:30:37.256 NotebookApp] Loading IPython parallel extension
#
#
#
# [I 15:30:37.262 NotebookApp] The port 8888 is already in use, trying another port.
#
#
#
# Traceback (most recent call last):
#
#
#
#   File "/home/halil/.local/bin/jupyter-notebook", line 8, in <module>
#
#
#
#
#
# sys.exit(main())
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# ^
#
# ^
#
# ^
#
# ^
#
# ^
#
# ^
#
#
#
#
#
#   File "/home/halil/.local/lib/python3.12/site-packages/jupyter_core/application.py", line 277, in launch_instance
#
#
#
#
#
# return super().launch_instance(argv=argv, **kwargs)
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# ^
#
# ^
#
# ^
#
# ^
#
# ^
#
# ^
#
# ^
#
# ^
#
# ^
#
# ^
#
# ^
#
# ^
#
# ^
#
# ^
#
# ^
#
# ^
#
# ^
#
# ^
#
# ^
#
# ^
#
# ^
#
# ^
#
# ^
#
# ^
#
# ^
#
# ^^^^^^^^^^^^^^^^^^^
#
#   File "/home/halil/.local/lib/python3.12/site-packages/traitlets/config/application.py", line 1043, in launch_instance
#
#     app.start()
#
#   File "/home/halil/.local/lib/python3.12/site-packages/notebook/notebookapp.py", line 2320, in start
#
#     success = self._bind_http_server()
#
#               ^^^^^^^^^^^^^^^^^^^^^^^^
#
#   File "/home/halil/.local/lib/python3.12/site-packages/notebook/notebookapp.py", line 1795, in _bind_http_server
#
#     return self._bind_http_server_unix() if self.sock else self._bind_http_server_tcp()
#
#                                                            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#
#   File "/home/halil/.local/lib/python3.12/site-packages/notebook/notebookapp.py", line 1821, in _bind_http_server_tcp
#
#     self.http_server.listen(port, self.ip)
#
#   File "/home/halil/.local/lib/python3.12/site-packages/tornado/tcpserver.py", line 191, in listen
#
#     self.add_sockets(sockets)
#
#   File "/home/halil/.local/lib/python3.12/site-packages/tornado/tcpserver.py", line 204, in add_sockets
#
#     self._handlers[sock.fileno()] = add_accept_handler(
#
#                                     ^^^^^^^^^^^^^^^^^^^
#
#   File "/home/halil/.local/lib/python3.12/site-packages/tornado/netutil.py", line 247, in add_accept_handler
#
#     io_loop = IOLoop.current()
#
#               ^^^^^^^^^^^^^^^^
#
#   File "/home/halil/.local/lib/python3.12/site-packages/tornado/ioloop.py", line 265, in current
#
#     loop = asyncio.get_event_loop()
#
#            ^^
#
# ^^^^^^^^^^^^^^^^^^^^^^
#
#   File "/home/halil/.local/lib/python3.12/site-packages/nest_asyncio.py", line 45, in _get_event_loop
#
#     loop = events.get_event_loop_policy().get_event_loop()
#
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#
#   File "/usr/local/lib/python3.12/asyncio/events.py", line 676, in get_event_loop
#
#
#
#     raise RuntimeError('There is no current event loop in thread %r.'
#
# RuntimeError: There is no current event loop in thread 'MainThread'.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
PATH = '/home/halil/Belgeler/Kodlama calismalari/py/Patika/Intermadiate data science/data/bulldozers/' 

df=pd.read_csv(f'{PATH}Train.csv',low_memory=False,parse_dates=["saledate"])
# Out:
# Failed to start the Kernel.
#
# Jupyter server crashed. Unable to connect.
#
# Error code from Jupyter: 1
#
# /home/halil/.local/lib/python3.12/site-packages/traitlets/traitlets.py:2548: FutureWarning: Supporting extra quotes around strings is deprecated in traitlets 5.0. You can use '/home/halil/Belgeler/Kodlama calismalari/py/Patika/Intermadiate data science' instead of '"/home/halil/Belgeler/Kodlama calismalari/py/Patika/Intermadiate data science"' if you require traitlets >=5.
#
#   warn(
#
#
#
# [I 15:13:06.082 NotebookApp] Loading IPython parallel extension
#
#
#
# Traceback (most recent call last):
#
#   File "/home/halil/.local/bin/jupyter-notebook", line 8, in <module>
#
#
#
#     sys.exit(main())
#
#              ^^^^^^
#
#   File "/home/halil/.local/lib/python3.12/site-packages/jupyter_core/application.py", line 277, in launch_instance
#
#
#
#     return super().launch_instance(argv=argv, **kwargs)
#
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#
# ^^
#
#   File "/home/halil/.local/lib/python3.12/site-packages/traitlets/config/application.py", line 1043, in launch_instance
#
#
#
#     app.start()
#
#   File "/home/halil/.local/lib/python3.12/site-packages/notebook/notebookapp.py", line 2320, in start
#
#
#
#     success = self._bind_http_server()
#
#
#
#               ^^^^^^^^^^^^^^^^^^^^^^^^
#
#   File "/home/halil/.local/lib/python3.12/site-packages/notebook/notebookapp.py", line 1795, in _bind_http_server
#
#
#
#     return self._bind_http_server_unix() if self.sock else self._bind_http_server_tcp()
#
#
#
#                                                            ^^
#
# ^^^^^^^^^^^^^^^^^^^^^^^^^^
#
#   File "/home/halil/.local/lib/python3.12/site-packages/notebook/notebookapp.py", line 1821, in _bind_http_server_tcp
#
#
#
#     self.http_server.listen(port, self.ip)
#
#
#
#   File "/home/halil/.local/lib/python3.12/site-packages/tornado/tcpserver.py", line 191, in listen
#
#     self.add_sockets(sockets)
#
#
#
#   File "/home/halil/.local/lib/python3.12/site-packages/tornado/tcpserver.py", line 204, in add_sockets
#
#     self._handlers[sock.fileno()] = add_accept_handler(
#
#
#
#                               ^^^^^^^^^^^^^^^^^^^
#
#   File "/home/halil/.local/lib/python3.12/site-packages/tornado/netutil.py", line 247, in add_accept_handler
#
#
#
#     io_loop = IOLoop.current()
#
#               ^^^^^^^^^^^^^^^^
#
#   File "/home/halil/.local/lib/python3.12/site-packages/tornado/ioloop.py", line 265, in current
#
#     loop = asyncio.get_event_loop()
#
#            ^^^^
#
# ^^^^^^^^^^^^^^^^^^^^
#
#   File "/home/halil/.local/lib/python3.12/site-packages/nest_asyncio.py", line 45, in _get_event_loop
#
#     loop = events.get_event_loop_policy().get_event_loop()
#
#
#
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#
#   File "/usr/local/lib/python3.12/asyncio/events.py", line 676, in get_event_loop
#
#
#
#     raise RuntimeError('There is no current event loop in thread %r.'
#
# RuntimeError: There is no current event loop in thread 'MainThread'.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
df.head()
# Out:
# Failed to start the Kernel.
#
# Jupyter server crashed. Unable to connect.
#
# Error code from Jupyter: 1
#
# /home/halil/.local/lib/python3.12/site-packages/traitlets/traitlets.py:2548: FutureWarning: Supporting extra quotes around strings is deprecated in traitlets 5.0. You can use '/home/halil/Belgeler/Kodlama calismalari/py/Patika/Intermadiate data science' instead of '"/home/halil/Belgeler/Kodlama calismalari/py/Patika/Intermadiate data science"' if you require traitlets >=5.
#
#   warn(
#
#
#
# [I 15:13:06.082 NotebookApp] Loading IPython parallel extension
#
#
#
# Traceback (most recent call last):
#
#   File "/home/halil/.local/bin/jupyter-notebook", line 8, in <module>
#
#
#
#     sys.exit(main())
#
#              ^^^^^^
#
#   File "/home/halil/.local/lib/python3.12/site-packages/jupyter_core/application.py", line 277, in launch_instance
#
#
#
#     return super().launch_instance(argv=argv, **kwargs)
#
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#
# ^^
#
#   File "/home/halil/.local/lib/python3.12/site-packages/traitlets/config/application.py", line 1043, in launch_instance
#
#
#
#     app.start()
#
#   File "/home/halil/.local/lib/python3.12/site-packages/notebook/notebookapp.py", line 2320, in start
#
#
#
#     success = self._bind_http_server()
#
#
#
#               ^^^^^^^^^^^^^^^^^^^^^^^^
#
#   File "/home/halil/.local/lib/python3.12/site-packages/notebook/notebookapp.py", line 1795, in _bind_http_server
#
#
#
#     return self._bind_http_server_unix() if self.sock else self._bind_http_server_tcp()
#
#
#
#                                                            ^^
#
# ^^^^^^^^^^^^^^^^^^^^^^^^^^
#
#   File "/home/halil/.local/lib/python3.12/site-packages/notebook/notebookapp.py", line 1821, in _bind_http_server_tcp
#
#
#
#     self.http_server.listen(port, self.ip)
#
#
#
#   File "/home/halil/.local/lib/python3.12/site-packages/tornado/tcpserver.py", line 191, in listen
#
#     self.add_sockets(sockets)
#
#
#
#   File "/home/halil/.local/lib/python3.12/site-packages/tornado/tcpserver.py", line 204, in add_sockets
#
#     self._handlers[sock.fileno()] = add_accept_handler(
#
#
#
#                               ^^^^^^^^^^^^^^^^^^^
#
#   File "/home/halil/.local/lib/python3.12/site-packages/tornado/netutil.py", line 247, in add_accept_handler
#
#
#
#     io_loop = IOLoop.current()
#
#               ^^^^^^^^^^^^^^^^
#
#   File "/home/halil/.local/lib/python3.12/site-packages/tornado/ioloop.py", line 265, in current
#
#     loop = asyncio.get_event_loop()
#
#            ^^^^
#
# ^^^^^^^^^^^^^^^^^^^^
#
#   File "/home/halil/.local/lib/python3.12/site-packages/nest_asyncio.py", line 45, in _get_event_loop
#
#     loop = events.get_event_loop_policy().get_event_loop()
#
#
#
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#
#   File "/usr/local/lib/python3.12/asyncio/events.py", line 676, in get_event_loop
#
#
#
#     raise RuntimeError('There is no current event loop in thread %r.'
#
# RuntimeError: There is no current event loop in thread 'MainThread'.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %% [markdown]
# ## RMSLE

# %%
df['SalePriceLog'] = np.log(df.SalePrice)
# Out:
# Failed to start the Kernel.
#
# Jupyter server crashed. Unable to connect.
#
# Error code from Jupyter: 1
#
# /home/halil/.local/lib/python3.12/site-packages/traitlets/traitlets.py:2548: FutureWarning: Supporting extra quotes around strings is deprecated in traitlets 5.0. You can use '/home/halil/Belgeler/Kodlama calismalari/py/Patika/Intermadiate data science' instead of '"/home/halil/Belgeler/Kodlama calismalari/py/Patika/Intermadiate data science"' if you require traitlets >=5.
#
#   warn(
#
#
#
# [I 15:13:06.082 NotebookApp] Loading IPython parallel extension
#
#
#
# Traceback (most recent call last):
#
#   File "/home/halil/.local/bin/jupyter-notebook", line 8, in <module>
#
#
#
#     sys.exit(main())
#
#              ^^^^^^
#
#   File "/home/halil/.local/lib/python3.12/site-packages/jupyter_core/application.py", line 277, in launch_instance
#
#
#
#     return super().launch_instance(argv=argv, **kwargs)
#
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#
# ^^
#
#   File "/home/halil/.local/lib/python3.12/site-packages/traitlets/config/application.py", line 1043, in launch_instance
#
#
#
#     app.start()
#
#   File "/home/halil/.local/lib/python3.12/site-packages/notebook/notebookapp.py", line 2320, in start
#
#
#
#     success = self._bind_http_server()
#
#
#
#               ^^^^^^^^^^^^^^^^^^^^^^^^
#
#   File "/home/halil/.local/lib/python3.12/site-packages/notebook/notebookapp.py", line 1795, in _bind_http_server
#
#
#
#     return self._bind_http_server_unix() if self.sock else self._bind_http_server_tcp()
#
#
#
#                                                            ^^
#
# ^^^^^^^^^^^^^^^^^^^^^^^^^^
#
#   File "/home/halil/.local/lib/python3.12/site-packages/notebook/notebookapp.py", line 1821, in _bind_http_server_tcp
#
#
#
#     self.http_server.listen(port, self.ip)
#
#
#
#   File "/home/halil/.local/lib/python3.12/site-packages/tornado/tcpserver.py", line 191, in listen
#
#     self.add_sockets(sockets)
#
#
#
#   File "/home/halil/.local/lib/python3.12/site-packages/tornado/tcpserver.py", line 204, in add_sockets
#
#     self._handlers[sock.fileno()] = add_accept_handler(
#
#
#
#                               ^^^^^^^^^^^^^^^^^^^
#
#   File "/home/halil/.local/lib/python3.12/site-packages/tornado/netutil.py", line 247, in add_accept_handler
#
#
#
#     io_loop = IOLoop.current()
#
#               ^^^^^^^^^^^^^^^^
#
#   File "/home/halil/.local/lib/python3.12/site-packages/tornado/ioloop.py", line 265, in current
#
#     loop = asyncio.get_event_loop()
#
#            ^^^^
#
# ^^^^^^^^^^^^^^^^^^^^
#
#   File "/home/halil/.local/lib/python3.12/site-packages/nest_asyncio.py", line 45, in _get_event_loop
#
#     loop = events.get_event_loop_policy().get_event_loop()
#
#
#
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#
#   File "/usr/local/lib/python3.12/asyncio/events.py", line 676, in get_event_loop
#
#
#
#     raise RuntimeError('There is no current event loop in thread %r.'
#
# RuntimeError: There is no current event loop in thread 'MainThread'.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
df[['SalePrice','SalePriceLog']].head()
# Out:
# Failed to start the Kernel.
#
# Jupyter server crashed. Unable to connect.
#
# Error code from Jupyter: 1
#
# /home/halil/.local/lib/python3.12/site-packages/traitlets/traitlets.py:2548: FutureWarning: Supporting extra quotes around strings is deprecated in traitlets 5.0. You can use '/home/halil/Belgeler/Kodlama calismalari/py/Patika/Intermadiate data science' instead of '"/home/halil/Belgeler/Kodlama calismalari/py/Patika/Intermadiate data science"' if you require traitlets >=5.
#
#   warn(
#
#
#
# [I 15:13:06.082 NotebookApp] Loading IPython parallel extension
#
#
#
# Traceback (most recent call last):
#
#   File "/home/halil/.local/bin/jupyter-notebook", line 8, in <module>
#
#
#
#     sys.exit(main())
#
#              ^^^^^^
#
#   File "/home/halil/.local/lib/python3.12/site-packages/jupyter_core/application.py", line 277, in launch_instance
#
#
#
#     return super().launch_instance(argv=argv, **kwargs)
#
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#
# ^^
#
#   File "/home/halil/.local/lib/python3.12/site-packages/traitlets/config/application.py", line 1043, in launch_instance
#
#
#
#     app.start()
#
#   File "/home/halil/.local/lib/python3.12/site-packages/notebook/notebookapp.py", line 2320, in start
#
#
#
#     success = self._bind_http_server()
#
#
#
#               ^^^^^^^^^^^^^^^^^^^^^^^^
#
#   File "/home/halil/.local/lib/python3.12/site-packages/notebook/notebookapp.py", line 1795, in _bind_http_server
#
#
#
#     return self._bind_http_server_unix() if self.sock else self._bind_http_server_tcp()
#
#
#
#                                                            ^^
#
# ^^^^^^^^^^^^^^^^^^^^^^^^^^
#
#   File "/home/halil/.local/lib/python3.12/site-packages/notebook/notebookapp.py", line 1821, in _bind_http_server_tcp
#
#
#
#     self.http_server.listen(port, self.ip)
#
#
#
#   File "/home/halil/.local/lib/python3.12/site-packages/tornado/tcpserver.py", line 191, in listen
#
#     self.add_sockets(sockets)
#
#
#
#   File "/home/halil/.local/lib/python3.12/site-packages/tornado/tcpserver.py", line 204, in add_sockets
#
#     self._handlers[sock.fileno()] = add_accept_handler(
#
#
#
#                               ^^^^^^^^^^^^^^^^^^^
#
#   File "/home/halil/.local/lib/python3.12/site-packages/tornado/netutil.py", line 247, in add_accept_handler
#
#
#
#     io_loop = IOLoop.current()
#
#               ^^^^^^^^^^^^^^^^
#
#   File "/home/halil/.local/lib/python3.12/site-packages/tornado/ioloop.py", line 265, in current
#
#     loop = asyncio.get_event_loop()
#
#            ^^^^
#
# ^^^^^^^^^^^^^^^^^^^^
#
#   File "/home/halil/.local/lib/python3.12/site-packages/nest_asyncio.py", line 45, in _get_event_loop
#
#     loop = events.get_event_loop_policy().get_event_loop()
#
#
#
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#
#   File "/usr/local/lib/python3.12/asyncio/events.py", line 676, in get_event_loop
#
#
#
#     raise RuntimeError('There is no current event loop in thread %r.'
#
# RuntimeError: There is no current event loop in thread 'MainThread'.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
df["UsageBand"]
# Out:
# Failed to start the Kernel.
#
# Jupyter server crashed. Unable to connect.
#
# Error code from Jupyter: 1
#
# /home/halil/.local/lib/python3.12/site-packages/traitlets/traitlets.py:2548: FutureWarning: Supporting extra quotes around strings is deprecated in traitlets 5.0. You can use '/home/halil/Belgeler/Kodlama calismalari/py/Patika/Intermadiate data science' instead of '"/home/halil/Belgeler/Kodlama calismalari/py/Patika/Intermadiate data science"' if you require traitlets >=5.
#
#   warn(
#
#
#
# [I 15:13:06.082 NotebookApp] Loading IPython parallel extension
#
#
#
# Traceback (most recent call last):
#
#   File "/home/halil/.local/bin/jupyter-notebook", line 8, in <module>
#
#
#
#     sys.exit(main())
#
#              ^^^^^^
#
#   File "/home/halil/.local/lib/python3.12/site-packages/jupyter_core/application.py", line 277, in launch_instance
#
#
#
#     return super().launch_instance(argv=argv, **kwargs)
#
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#
# ^^
#
#   File "/home/halil/.local/lib/python3.12/site-packages/traitlets/config/application.py", line 1043, in launch_instance
#
#
#
#     app.start()
#
#   File "/home/halil/.local/lib/python3.12/site-packages/notebook/notebookapp.py", line 2320, in start
#
#
#
#     success = self._bind_http_server()
#
#
#
#               ^^^^^^^^^^^^^^^^^^^^^^^^
#
#   File "/home/halil/.local/lib/python3.12/site-packages/notebook/notebookapp.py", line 1795, in _bind_http_server
#
#
#
#     return self._bind_http_server_unix() if self.sock else self._bind_http_server_tcp()
#
#
#
#                                                            ^^
#
# ^^^^^^^^^^^^^^^^^^^^^^^^^^
#
#   File "/home/halil/.local/lib/python3.12/site-packages/notebook/notebookapp.py", line 1821, in _bind_http_server_tcp
#
#
#
#     self.http_server.listen(port, self.ip)
#
#
#
#   File "/home/halil/.local/lib/python3.12/site-packages/tornado/tcpserver.py", line 191, in listen
#
#     self.add_sockets(sockets)
#
#
#
#   File "/home/halil/.local/lib/python3.12/site-packages/tornado/tcpserver.py", line 204, in add_sockets
#
#     self._handlers[sock.fileno()] = add_accept_handler(
#
#
#
#                               ^^^^^^^^^^^^^^^^^^^
#
#   File "/home/halil/.local/lib/python3.12/site-packages/tornado/netutil.py", line 247, in add_accept_handler
#
#
#
#     io_loop = IOLoop.current()
#
#               ^^^^^^^^^^^^^^^^
#
#   File "/home/halil/.local/lib/python3.12/site-packages/tornado/ioloop.py", line 265, in current
#
#     loop = asyncio.get_event_loop()
#
#            ^^^^
#
# ^^^^^^^^^^^^^^^^^^^^
#
#   File "/home/halil/.local/lib/python3.12/site-packages/nest_asyncio.py", line 45, in _get_event_loop
#
#     loop = events.get_event_loop_policy().get_event_loop()
#
#
#
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#
#   File "/usr/local/lib/python3.12/asyncio/events.py", line 676, in get_event_loop
#
#
#
#     raise RuntimeError('There is no current event loop in thread %r.'
#
# RuntimeError: There is no current event loop in thread 'MainThread'.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
for n,c in df.items():
    print(n)
    print("----------")
    print(c)
    break
# Out:
# Failed to start the Kernel.
#
# Jupyter server crashed. Unable to connect.
#
# Error code from Jupyter: 1
#
# /home/halil/.local/lib/python3.12/site-packages/traitlets/traitlets.py:2548: FutureWarning: Supporting extra quotes around strings is deprecated in traitlets 5.0. You can use '/home/halil/Belgeler/Kodlama calismalari/py/Patika/Intermadiate data science' instead of '"/home/halil/Belgeler/Kodlama calismalari/py/Patika/Intermadiate data science"' if you require traitlets >=5.
#
#   warn(
#
#
#
# [I 15:34:58.784 NotebookApp] Loading IPython parallel extension
#
#
#
# [I 15:34:58.787 NotebookApp] The port 8888 is already in use, trying another port.
#
#
#
# Traceback (most recent call last):
#
#   File "/home/halil/.local/bin/jupyter-notebook", line 8, in <module>
#
#
#
#     sys.exit(main())
#
#              ^^^^^^
#
#   File "/home/halil/.local/lib/python3.12/site-packages/jupyter_core/application.py", line 277, in launch_instance
#
#
#
#     return super().launch_instance(argv=argv, **kwargs)
#
#
#
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#
# ^^^^^
#
#   File "/home/halil/.local/lib/python3.12/site-packages/traitlets/config/application.py", line 1043, in launch_instance
#
#
#
#     app.start()
#
#
#
#   File "/home/halil/.local/lib/python3.12/site-packages/notebook/notebookapp.py", line 2320, in start
#
#
#
#     success = self._bind_http_server()
#
#
#
#             ^^^^^^^^^^^^^^^^^^^^^^^^
#
#   File "/home/halil/.local/lib/python3.12/site-packages/notebook/notebookapp.py", line 1795, in _bind_http_server
#
#
#
#     return self._bind_http_server_unix() if self.sock else self._bind_http_server_tcp()
#
#
#
#
#
#   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#
#   File "/home/halil/.local/lib/python3.12/site-packages/notebook/notebookapp.py", line 1821, in _bind_http_server_tcp
#
#
#
#     self.http_server.listen(port, self.ip)
#
#
#
#   File "/home/halil/.local/lib/python3.12/site-packages/tornado/tcpserver.py", line 191, in listen
#
#
#
#     self.add_sockets(sockets)
#
#
#
#   File "/home/halil/.local/lib/python3.12/site-packages/tornado/tcpserver.py", line 204, in add_sockets
#
#
#
#     self._handlers[sock.fileno()] = add_accept_handler(
#
#
#
#                           ^^^^^^
#
# ^^^^^^^^^^^^^
#
#   File "/home/halil/.local/lib/python3.12/site-packages/tornado/netutil.py", line 247, in add_accept_handler
#
#
#
#     io_loop = IOLoop.current()
#
#
#
#               ^^^^^^^^^^^^^
#
# ^^^
#
#   File "/home/halil/.local/lib/python3.12/site-packages/tornado/ioloop.py", line 265, in current
#
#
#
#     loop = asyncio.get_event_loop()
#
#
#
#            ^^^^^^^^^^^^^^^^^^
#
# ^^^^^^
#
#   File "/home/halil/.local/lib/python3.12/site-packages/nest_asyncio.py", line 45, in _get_event_loop
#
#
#
#     loop = events.get_event_loop_policy().get_event_loop()
#
#
#
#  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#
# ^^^^^^^^^^^^^^^^^
#
#   File "/usr/local/lib/python3.12/asyncio/events.py", line 676, in get_event_loop
#
#
#
#     raise RuntimeError('There is no current event loop in thread %r.'
#
# RuntimeError: There is no current event loop in thread 'MainThread'.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
def train_cats(df):
    for n,c in df.items():
        if is_string_dtype(c):
            df[n]=c.astype("category").cat.as_ordered()
# Out:
# Failed to start the Kernel.
#
# Jupyter server crashed. Unable to connect.
#
# Error code from Jupyter: 1
#
# /home/halil/.local/lib/python3.12/site-packages/traitlets/traitlets.py:2548: FutureWarning: Supporting extra quotes around strings is deprecated in traitlets 5.0. You can use '/home/halil/Belgeler/Kodlama calismalari/py/Patika/Intermadiate data science' instead of '"/home/halil/Belgeler/Kodlama calismalari/py/Patika/Intermadiate data science"' if you require traitlets >=5.
#
#   warn(
#
#
#
# [I 15:13:06.082 NotebookApp] Loading IPython parallel extension
#
#
#
# Traceback (most recent call last):
#
#   File "/home/halil/.local/bin/jupyter-notebook", line 8, in <module>
#
#
#
#     sys.exit(main())
#
#              ^^^^^^
#
#   File "/home/halil/.local/lib/python3.12/site-packages/jupyter_core/application.py", line 277, in launch_instance
#
#
#
#     return super().launch_instance(argv=argv, **kwargs)
#
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#
# ^^
#
#   File "/home/halil/.local/lib/python3.12/site-packages/traitlets/config/application.py", line 1043, in launch_instance
#
#
#
#     app.start()
#
#   File "/home/halil/.local/lib/python3.12/site-packages/notebook/notebookapp.py", line 2320, in start
#
#
#
#     success = self._bind_http_server()
#
#
#
#               ^^^^^^^^^^^^^^^^^^^^^^^^
#
#   File "/home/halil/.local/lib/python3.12/site-packages/notebook/notebookapp.py", line 1795, in _bind_http_server
#
#
#
#     return self._bind_http_server_unix() if self.sock else self._bind_http_server_tcp()
#
#
#
#                                                            ^^
#
# ^^^^^^^^^^^^^^^^^^^^^^^^^^
#
#   File "/home/halil/.local/lib/python3.12/site-packages/notebook/notebookapp.py", line 1821, in _bind_http_server_tcp
#
#
#
#     self.http_server.listen(port, self.ip)
#
#
#
#   File "/home/halil/.local/lib/python3.12/site-packages/tornado/tcpserver.py", line 191, in listen
#
#     self.add_sockets(sockets)
#
#
#
#   File "/home/halil/.local/lib/python3.12/site-packages/tornado/tcpserver.py", line 204, in add_sockets
#
#     self._handlers[sock.fileno()] = add_accept_handler(
#
#
#
#                               ^^^^^^^^^^^^^^^^^^^
#
#   File "/home/halil/.local/lib/python3.12/site-packages/tornado/netutil.py", line 247, in add_accept_handler
#
#
#
#     io_loop = IOLoop.current()
#
#               ^^^^^^^^^^^^^^^^
#
#   File "/home/halil/.local/lib/python3.12/site-packages/tornado/ioloop.py", line 265, in current
#
#     loop = asyncio.get_event_loop()
#
#            ^^^^
#
# ^^^^^^^^^^^^^^^^^^^^
#
#   File "/home/halil/.local/lib/python3.12/site-packages/nest_asyncio.py", line 45, in _get_event_loop
#
#     loop = events.get_event_loop_policy().get_event_loop()
#
#
#
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#
#   File "/usr/local/lib/python3.12/asyncio/events.py", line 676, in get_event_loop
#
#
#
#     raise RuntimeError('There is no current event loop in thread %r.'
#
# RuntimeError: There is no current event loop in thread 'MainThread'.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
def apply_cats(df,train):
    for n,c in df.items():
        if train[n].dype == "category":
            df[n] = pd.Categorical(c,categories = train[n].cat.categories , ordered= True)
# Out:
# Failed to start the Kernel.
#
# Jupyter server crashed. Unable to connect.
#
# Error code from Jupyter: 1
#
# /home/halil/.local/lib/python3.12/site-packages/traitlets/traitlets.py:2548: FutureWarning: Supporting extra quotes around strings is deprecated in traitlets 5.0. You can use '/home/halil/Belgeler/Kodlama calismalari/py/Patika/Intermadiate data science' instead of '"/home/halil/Belgeler/Kodlama calismalari/py/Patika/Intermadiate data science"' if you require traitlets >=5.
#
#   warn(
#
#
#
# [I 15:13:06.082 NotebookApp] Loading IPython parallel extension
#
#
#
# Traceback (most recent call last):
#
#   File "/home/halil/.local/bin/jupyter-notebook", line 8, in <module>
#
#
#
#     sys.exit(main())
#
#              ^^^^^^
#
#   File "/home/halil/.local/lib/python3.12/site-packages/jupyter_core/application.py", line 277, in launch_instance
#
#
#
#     return super().launch_instance(argv=argv, **kwargs)
#
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#
# ^^
#
#   File "/home/halil/.local/lib/python3.12/site-packages/traitlets/config/application.py", line 1043, in launch_instance
#
#
#
#     app.start()
#
#   File "/home/halil/.local/lib/python3.12/site-packages/notebook/notebookapp.py", line 2320, in start
#
#
#
#     success = self._bind_http_server()
#
#
#
#               ^^^^^^^^^^^^^^^^^^^^^^^^
#
#   File "/home/halil/.local/lib/python3.12/site-packages/notebook/notebookapp.py", line 1795, in _bind_http_server
#
#
#
#     return self._bind_http_server_unix() if self.sock else self._bind_http_server_tcp()
#
#
#
#                                                            ^^
#
# ^^^^^^^^^^^^^^^^^^^^^^^^^^
#
#   File "/home/halil/.local/lib/python3.12/site-packages/notebook/notebookapp.py", line 1821, in _bind_http_server_tcp
#
#
#
#     self.http_server.listen(port, self.ip)
#
#
#
#   File "/home/halil/.local/lib/python3.12/site-packages/tornado/tcpserver.py", line 191, in listen
#
#     self.add_sockets(sockets)
#
#
#
#   File "/home/halil/.local/lib/python3.12/site-packages/tornado/tcpserver.py", line 204, in add_sockets
#
#     self._handlers[sock.fileno()] = add_accept_handler(
#
#
#
#                               ^^^^^^^^^^^^^^^^^^^
#
#   File "/home/halil/.local/lib/python3.12/site-packages/tornado/netutil.py", line 247, in add_accept_handler
#
#
#
#     io_loop = IOLoop.current()
#
#               ^^^^^^^^^^^^^^^^
#
#   File "/home/halil/.local/lib/python3.12/site-packages/tornado/ioloop.py", line 265, in current
#
#     loop = asyncio.get_event_loop()
#
#            ^^^^
#
# ^^^^^^^^^^^^^^^^^^^^
#
#   File "/home/halil/.local/lib/python3.12/site-packages/nest_asyncio.py", line 45, in _get_event_loop
#
#     loop = events.get_event_loop_policy().get_event_loop()
#
#
#
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#
#   File "/usr/local/lib/python3.12/asyncio/events.py", line 676, in get_event_loop
#
#
#
#     raise RuntimeError('There is no current event loop in thread %r.'
#
# RuntimeError: There is no current event loop in thread 'MainThread'.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
train_cats(df)
# Out:
# Failed to start the Kernel.
#
# Jupyter server crashed. Unable to connect.
#
# Error code from Jupyter: 1
#
# /home/halil/.local/lib/python3.12/site-packages/traitlets/traitlets.py:2548: FutureWarning: Supporting extra quotes around strings is deprecated in traitlets 5.0. You can use '/home/halil/Belgeler/Kodlama calismalari/py/Patika/Intermadiate data science' instead of '"/home/halil/Belgeler/Kodlama calismalari/py/Patika/Intermadiate data science"' if you require traitlets >=5.
#
#   warn(
#
#
#
# [I 15:13:06.082 NotebookApp] Loading IPython parallel extension
#
#
#
# Traceback (most recent call last):
#
#   File "/home/halil/.local/bin/jupyter-notebook", line 8, in <module>
#
#
#
#     sys.exit(main())
#
#              ^^^^^^
#
#   File "/home/halil/.local/lib/python3.12/site-packages/jupyter_core/application.py", line 277, in launch_instance
#
#
#
#     return super().launch_instance(argv=argv, **kwargs)
#
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#
# ^^
#
#   File "/home/halil/.local/lib/python3.12/site-packages/traitlets/config/application.py", line 1043, in launch_instance
#
#
#
#     app.start()
#
#   File "/home/halil/.local/lib/python3.12/site-packages/notebook/notebookapp.py", line 2320, in start
#
#
#
#     success = self._bind_http_server()
#
#
#
#               ^^^^^^^^^^^^^^^^^^^^^^^^
#
#   File "/home/halil/.local/lib/python3.12/site-packages/notebook/notebookapp.py", line 1795, in _bind_http_server
#
#
#
#     return self._bind_http_server_unix() if self.sock else self._bind_http_server_tcp()
#
#
#
#                                                            ^^
#
# ^^^^^^^^^^^^^^^^^^^^^^^^^^
#
#   File "/home/halil/.local/lib/python3.12/site-packages/notebook/notebookapp.py", line 1821, in _bind_http_server_tcp
#
#
#
#     self.http_server.listen(port, self.ip)
#
#
#
#   File "/home/halil/.local/lib/python3.12/site-packages/tornado/tcpserver.py", line 191, in listen
#
#     self.add_sockets(sockets)
#
#
#
#   File "/home/halil/.local/lib/python3.12/site-packages/tornado/tcpserver.py", line 204, in add_sockets
#
#     self._handlers[sock.fileno()] = add_accept_handler(
#
#
#
#                               ^^^^^^^^^^^^^^^^^^^
#
#   File "/home/halil/.local/lib/python3.12/site-packages/tornado/netutil.py", line 247, in add_accept_handler
#
#
#
#     io_loop = IOLoop.current()
#
#               ^^^^^^^^^^^^^^^^
#
#   File "/home/halil/.local/lib/python3.12/site-packages/tornado/ioloop.py", line 265, in current
#
#     loop = asyncio.get_event_loop()
#
#            ^^^^
#
# ^^^^^^^^^^^^^^^^^^^^
#
#   File "/home/halil/.local/lib/python3.12/site-packages/nest_asyncio.py", line 45, in _get_event_loop
#
#     loop = events.get_event_loop_policy().get_event_loop()
#
#
#
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#
#   File "/usr/local/lib/python3.12/asyncio/events.py", line 676, in get_event_loop
#
#
#
#     raise RuntimeError('There is no current event loop in thread %r.'
#
# RuntimeError: There is no current event loop in thread 'MainThread'.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
df["UsageBand"]
# Out:
# Failed to start the Kernel.
#
# Jupyter server crashed. Unable to connect.
#
# Error code from Jupyter: 1
#
# /home/halil/.local/lib/python3.12/site-packages/traitlets/traitlets.py:2548: FutureWarning: Supporting extra quotes around strings is deprecated in traitlets 5.0. You can use '/home/halil/Belgeler/Kodlama calismalari/py/Patika/Intermadiate data science' instead of '"/home/halil/Belgeler/Kodlama calismalari/py/Patika/Intermadiate data science"' if you require traitlets >=5.
#
#   warn(
#
#
#
# [I 15:13:06.082 NotebookApp] Loading IPython parallel extension
#
#
#
# Traceback (most recent call last):
#
#   File "/home/halil/.local/bin/jupyter-notebook", line 8, in <module>
#
#
#
#     sys.exit(main())
#
#              ^^^^^^
#
#   File "/home/halil/.local/lib/python3.12/site-packages/jupyter_core/application.py", line 277, in launch_instance
#
#
#
#     return super().launch_instance(argv=argv, **kwargs)
#
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#
# ^^
#
#   File "/home/halil/.local/lib/python3.12/site-packages/traitlets/config/application.py", line 1043, in launch_instance
#
#
#
#     app.start()
#
#   File "/home/halil/.local/lib/python3.12/site-packages/notebook/notebookapp.py", line 2320, in start
#
#
#
#     success = self._bind_http_server()
#
#
#
#               ^^^^^^^^^^^^^^^^^^^^^^^^
#
#   File "/home/halil/.local/lib/python3.12/site-packages/notebook/notebookapp.py", line 1795, in _bind_http_server
#
#
#
#     return self._bind_http_server_unix() if self.sock else self._bind_http_server_tcp()
#
#
#
#                                                            ^^
#
# ^^^^^^^^^^^^^^^^^^^^^^^^^^
#
#   File "/home/halil/.local/lib/python3.12/site-packages/notebook/notebookapp.py", line 1821, in _bind_http_server_tcp
#
#
#
#     self.http_server.listen(port, self.ip)
#
#
#
#   File "/home/halil/.local/lib/python3.12/site-packages/tornado/tcpserver.py", line 191, in listen
#
#     self.add_sockets(sockets)
#
#
#
#   File "/home/halil/.local/lib/python3.12/site-packages/tornado/tcpserver.py", line 204, in add_sockets
#
#     self._handlers[sock.fileno()] = add_accept_handler(
#
#
#
#                               ^^^^^^^^^^^^^^^^^^^
#
#   File "/home/halil/.local/lib/python3.12/site-packages/tornado/netutil.py", line 247, in add_accept_handler
#
#
#
#     io_loop = IOLoop.current()
#
#               ^^^^^^^^^^^^^^^^
#
#   File "/home/halil/.local/lib/python3.12/site-packages/tornado/ioloop.py", line 265, in current
#
#     loop = asyncio.get_event_loop()
#
#            ^^^^
#
# ^^^^^^^^^^^^^^^^^^^^
#
#   File "/home/halil/.local/lib/python3.12/site-packages/nest_asyncio.py", line 45, in _get_event_loop
#
#     loop = events.get_event_loop_policy().get_event_loop()
#
#
#
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#
#   File "/usr/local/lib/python3.12/asyncio/events.py", line 676, in get_event_loop
#
#
#
#     raise RuntimeError('There is no current event loop in thread %r.'
#
# RuntimeError: There is no current event loop in thread 'MainThread'.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
df["UsageBand"].cat.categories
# Out:
# Failed to start the Kernel.
#
# Jupyter server crashed. Unable to connect.
#
# Error code from Jupyter: 1
#
# /home/halil/.local/lib/python3.12/site-packages/traitlets/traitlets.py:2548: FutureWarning: Supporting extra quotes around strings is deprecated in traitlets 5.0. You can use '/home/halil/Belgeler/Kodlama calismalari/py/Patika/Intermadiate data science' instead of '"/home/halil/Belgeler/Kodlama calismalari/py/Patika/Intermadiate data science"' if you require traitlets >=5.
#
#   warn(
#
#
#
# [I 15:13:06.082 NotebookApp] Loading IPython parallel extension
#
#
#
# Traceback (most recent call last):
#
#   File "/home/halil/.local/bin/jupyter-notebook", line 8, in <module>
#
#
#
#     sys.exit(main())
#
#              ^^^^^^
#
#   File "/home/halil/.local/lib/python3.12/site-packages/jupyter_core/application.py", line 277, in launch_instance
#
#
#
#     return super().launch_instance(argv=argv, **kwargs)
#
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#
# ^^
#
#   File "/home/halil/.local/lib/python3.12/site-packages/traitlets/config/application.py", line 1043, in launch_instance
#
#
#
#     app.start()
#
#   File "/home/halil/.local/lib/python3.12/site-packages/notebook/notebookapp.py", line 2320, in start
#
#
#
#     success = self._bind_http_server()
#
#
#
#               ^^^^^^^^^^^^^^^^^^^^^^^^
#
#   File "/home/halil/.local/lib/python3.12/site-packages/notebook/notebookapp.py", line 1795, in _bind_http_server
#
#
#
#     return self._bind_http_server_unix() if self.sock else self._bind_http_server_tcp()
#
#
#
#                                                            ^^
#
# ^^^^^^^^^^^^^^^^^^^^^^^^^^
#
#   File "/home/halil/.local/lib/python3.12/site-packages/notebook/notebookapp.py", line 1821, in _bind_http_server_tcp
#
#
#
#     self.http_server.listen(port, self.ip)
#
#
#
#   File "/home/halil/.local/lib/python3.12/site-packages/tornado/tcpserver.py", line 191, in listen
#
#     self.add_sockets(sockets)
#
#
#
#   File "/home/halil/.local/lib/python3.12/site-packages/tornado/tcpserver.py", line 204, in add_sockets
#
#     self._handlers[sock.fileno()] = add_accept_handler(
#
#
#
#                               ^^^^^^^^^^^^^^^^^^^
#
#   File "/home/halil/.local/lib/python3.12/site-packages/tornado/netutil.py", line 247, in add_accept_handler
#
#
#
#     io_loop = IOLoop.current()
#
#               ^^^^^^^^^^^^^^^^
#
#   File "/home/halil/.local/lib/python3.12/site-packages/tornado/ioloop.py", line 265, in current
#
#     loop = asyncio.get_event_loop()
#
#            ^^^^
#
# ^^^^^^^^^^^^^^^^^^^^
#
#   File "/home/halil/.local/lib/python3.12/site-packages/nest_asyncio.py", line 45, in _get_event_loop
#
#     loop = events.get_event_loop_policy().get_event_loop()
#
#
#
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#
#   File "/usr/local/lib/python3.12/asyncio/events.py", line 676, in get_event_loop
#
#
#
#     raise RuntimeError('There is no current event loop in thread %r.'
#
# RuntimeError: There is no current event loop in thread 'MainThread'.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
df["UsageBand"].cat.set_categories(["High","Medium","Low"],ordered=True,inplace=True)
# Out:
# Failed to start the Kernel.
#
# Jupyter server crashed. Unable to connect.
#
# Error code from Jupyter: 1
#
# /home/halil/.local/lib/python3.12/site-packages/traitlets/traitlets.py:2548: FutureWarning: Supporting extra quotes around strings is deprecated in traitlets 5.0. You can use '/home/halil/Belgeler/Kodlama calismalari/py/Patika/Intermadiate data science' instead of '"/home/halil/Belgeler/Kodlama calismalari/py/Patika/Intermadiate data science"' if you require traitlets >=5.
#
#   warn(
#
#
#
# [I 15:13:06.082 NotebookApp] Loading IPython parallel extension
#
#
#
# Traceback (most recent call last):
#
#   File "/home/halil/.local/bin/jupyter-notebook", line 8, in <module>
#
#
#
#     sys.exit(main())
#
#              ^^^^^^
#
#   File "/home/halil/.local/lib/python3.12/site-packages/jupyter_core/application.py", line 277, in launch_instance
#
#
#
#     return super().launch_instance(argv=argv, **kwargs)
#
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#
# ^^
#
#   File "/home/halil/.local/lib/python3.12/site-packages/traitlets/config/application.py", line 1043, in launch_instance
#
#
#
#     app.start()
#
#   File "/home/halil/.local/lib/python3.12/site-packages/notebook/notebookapp.py", line 2320, in start
#
#
#
#     success = self._bind_http_server()
#
#
#
#               ^^^^^^^^^^^^^^^^^^^^^^^^
#
#   File "/home/halil/.local/lib/python3.12/site-packages/notebook/notebookapp.py", line 1795, in _bind_http_server
#
#
#
#     return self._bind_http_server_unix() if self.sock else self._bind_http_server_tcp()
#
#
#
#                                                            ^^
#
# ^^^^^^^^^^^^^^^^^^^^^^^^^^
#
#   File "/home/halil/.local/lib/python3.12/site-packages/notebook/notebookapp.py", line 1821, in _bind_http_server_tcp
#
#
#
#     self.http_server.listen(port, self.ip)
#
#
#
#   File "/home/halil/.local/lib/python3.12/site-packages/tornado/tcpserver.py", line 191, in listen
#
#     self.add_sockets(sockets)
#
#
#
#   File "/home/halil/.local/lib/python3.12/site-packages/tornado/tcpserver.py", line 204, in add_sockets
#
#     self._handlers[sock.fileno()] = add_accept_handler(
#
#
#
#                               ^^^^^^^^^^^^^^^^^^^
#
#   File "/home/halil/.local/lib/python3.12/site-packages/tornado/netutil.py", line 247, in add_accept_handler
#
#
#
#     io_loop = IOLoop.current()
#
#               ^^^^^^^^^^^^^^^^
#
#   File "/home/halil/.local/lib/python3.12/site-packages/tornado/ioloop.py", line 265, in current
#
#     loop = asyncio.get_event_loop()
#
#            ^^^^
#
# ^^^^^^^^^^^^^^^^^^^^
#
#   File "/home/halil/.local/lib/python3.12/site-packages/nest_asyncio.py", line 45, in _get_event_loop
#
#     loop = events.get_event_loop_policy().get_event_loop()
#
#
#
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#
#   File "/usr/local/lib/python3.12/asyncio/events.py", line 676, in get_event_loop
#
#
#
#     raise RuntimeError('There is no current event loop in thread %r.'
#
# RuntimeError: There is no current event loop in thread 'MainThread'.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
df["UsageBand"].cat.categories
# Out:
# Failed to start the Kernel.
#
# Jupyter server crashed. Unable to connect.
#
# Error code from Jupyter: 1
#
# /home/halil/.local/lib/python3.12/site-packages/traitlets/traitlets.py:2548: FutureWarning: Supporting extra quotes around strings is deprecated in traitlets 5.0. You can use '/home/halil/Belgeler/Kodlama calismalari/py/Patika/Intermadiate data science' instead of '"/home/halil/Belgeler/Kodlama calismalari/py/Patika/Intermadiate data science"' if you require traitlets >=5.
#
#   warn(
#
#
#
# [I 15:13:06.082 NotebookApp] Loading IPython parallel extension
#
#
#
# Traceback (most recent call last):
#
#   File "/home/halil/.local/bin/jupyter-notebook", line 8, in <module>
#
#
#
#     sys.exit(main())
#
#              ^^^^^^
#
#   File "/home/halil/.local/lib/python3.12/site-packages/jupyter_core/application.py", line 277, in launch_instance
#
#
#
#     return super().launch_instance(argv=argv, **kwargs)
#
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#
# ^^
#
#   File "/home/halil/.local/lib/python3.12/site-packages/traitlets/config/application.py", line 1043, in launch_instance
#
#
#
#     app.start()
#
#   File "/home/halil/.local/lib/python3.12/site-packages/notebook/notebookapp.py", line 2320, in start
#
#
#
#     success = self._bind_http_server()
#
#
#
#               ^^^^^^^^^^^^^^^^^^^^^^^^
#
#   File "/home/halil/.local/lib/python3.12/site-packages/notebook/notebookapp.py", line 1795, in _bind_http_server
#
#
#
#     return self._bind_http_server_unix() if self.sock else self._bind_http_server_tcp()
#
#
#
#                                                            ^^
#
# ^^^^^^^^^^^^^^^^^^^^^^^^^^
#
#   File "/home/halil/.local/lib/python3.12/site-packages/notebook/notebookapp.py", line 1821, in _bind_http_server_tcp
#
#
#
#     self.http_server.listen(port, self.ip)
#
#
#
#   File "/home/halil/.local/lib/python3.12/site-packages/tornado/tcpserver.py", line 191, in listen
#
#     self.add_sockets(sockets)
#
#
#
#   File "/home/halil/.local/lib/python3.12/site-packages/tornado/tcpserver.py", line 204, in add_sockets
#
#     self._handlers[sock.fileno()] = add_accept_handler(
#
#
#
#                               ^^^^^^^^^^^^^^^^^^^
#
#   File "/home/halil/.local/lib/python3.12/site-packages/tornado/netutil.py", line 247, in add_accept_handler
#
#
#
#     io_loop = IOLoop.current()
#
#               ^^^^^^^^^^^^^^^^
#
#   File "/home/halil/.local/lib/python3.12/site-packages/tornado/ioloop.py", line 265, in current
#
#     loop = asyncio.get_event_loop()
#
#            ^^^^
#
# ^^^^^^^^^^^^^^^^^^^^
#
#   File "/home/halil/.local/lib/python3.12/site-packages/nest_asyncio.py", line 45, in _get_event_loop
#
#     loop = events.get_event_loop_policy().get_event_loop()
#
#
#
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#
#   File "/usr/local/lib/python3.12/asyncio/events.py", line 676, in get_event_loop
#
#
#
#     raise RuntimeError('There is no current event loop in thread %r.'
#
# RuntimeError: There is no current event loop in thread 'MainThread'.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
df["UsageBand"].cat.codes
# Out:
# Failed to start the Kernel.
#
# Jupyter server crashed. Unable to connect.
#
# Error code from Jupyter: 1
#
# /home/halil/.local/lib/python3.12/site-packages/traitlets/traitlets.py:2548: FutureWarning: Supporting extra quotes around strings is deprecated in traitlets 5.0. You can use '/home/halil/Belgeler/Kodlama calismalari/py/Patika/Intermadiate data science' instead of '"/home/halil/Belgeler/Kodlama calismalari/py/Patika/Intermadiate data science"' if you require traitlets >=5.
#
#   warn(
#
#
#
# [I 15:13:06.082 NotebookApp] Loading IPython parallel extension
#
#
#
# Traceback (most recent call last):
#
#   File "/home/halil/.local/bin/jupyter-notebook", line 8, in <module>
#
#
#
#     sys.exit(main())
#
#              ^^^^^^
#
#   File "/home/halil/.local/lib/python3.12/site-packages/jupyter_core/application.py", line 277, in launch_instance
#
#
#
#     return super().launch_instance(argv=argv, **kwargs)
#
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#
# ^^
#
#   File "/home/halil/.local/lib/python3.12/site-packages/traitlets/config/application.py", line 1043, in launch_instance
#
#
#
#     app.start()
#
#   File "/home/halil/.local/lib/python3.12/site-packages/notebook/notebookapp.py", line 2320, in start
#
#
#
#     success = self._bind_http_server()
#
#
#
#               ^^^^^^^^^^^^^^^^^^^^^^^^
#
#   File "/home/halil/.local/lib/python3.12/site-packages/notebook/notebookapp.py", line 1795, in _bind_http_server
#
#
#
#     return self._bind_http_server_unix() if self.sock else self._bind_http_server_tcp()
#
#
#
#                                                            ^^
#
# ^^^^^^^^^^^^^^^^^^^^^^^^^^
#
#   File "/home/halil/.local/lib/python3.12/site-packages/notebook/notebookapp.py", line 1821, in _bind_http_server_tcp
#
#
#
#     self.http_server.listen(port, self.ip)
#
#
#
#   File "/home/halil/.local/lib/python3.12/site-packages/tornado/tcpserver.py", line 191, in listen
#
#     self.add_sockets(sockets)
#
#
#
#   File "/home/halil/.local/lib/python3.12/site-packages/tornado/tcpserver.py", line 204, in add_sockets
#
#     self._handlers[sock.fileno()] = add_accept_handler(
#
#
#
#                               ^^^^^^^^^^^^^^^^^^^
#
#   File "/home/halil/.local/lib/python3.12/site-packages/tornado/netutil.py", line 247, in add_accept_handler
#
#
#
#     io_loop = IOLoop.current()
#
#               ^^^^^^^^^^^^^^^^
#
#   File "/home/halil/.local/lib/python3.12/site-packages/tornado/ioloop.py", line 265, in current
#
#     loop = asyncio.get_event_loop()
#
#            ^^^^
#
# ^^^^^^^^^^^^^^^^^^^^
#
#   File "/home/halil/.local/lib/python3.12/site-packages/nest_asyncio.py", line 45, in _get_event_loop
#
#     loop = events.get_event_loop_policy().get_event_loop()
#
#
#
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#
#   File "/usr/local/lib/python3.12/asyncio/events.py", line 676, in get_event_loop
#
#
#
#     raise RuntimeError('There is no current event loop in thread %r.'
#
# RuntimeError: There is no current event loop in thread 'MainThread'.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
def numericalize(df,col,name):
    if not is_numeric_dtype(col):
        df[name]=col.cat.codes+1
# Out:
# Failed to start the Kernel.
#
# Jupyter server crashed. Unable to connect.
#
# Error code from Jupyter: 1
#
# /home/halil/.local/lib/python3.12/site-packages/traitlets/traitlets.py:2548: FutureWarning: Supporting extra quotes around strings is deprecated in traitlets 5.0. You can use '/home/halil/Belgeler/Kodlama calismalari/py/Patika/Intermadiate data science' instead of '"/home/halil/Belgeler/Kodlama calismalari/py/Patika/Intermadiate data science"' if you require traitlets >=5.
#
#   warn(
#
#
#
# [I 15:13:06.082 NotebookApp] Loading IPython parallel extension
#
#
#
# Traceback (most recent call last):
#
#   File "/home/halil/.local/bin/jupyter-notebook", line 8, in <module>
#
#
#
#     sys.exit(main())
#
#              ^^^^^^
#
#   File "/home/halil/.local/lib/python3.12/site-packages/jupyter_core/application.py", line 277, in launch_instance
#
#
#
#     return super().launch_instance(argv=argv, **kwargs)
#
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#
# ^^
#
#   File "/home/halil/.local/lib/python3.12/site-packages/traitlets/config/application.py", line 1043, in launch_instance
#
#
#
#     app.start()
#
#   File "/home/halil/.local/lib/python3.12/site-packages/notebook/notebookapp.py", line 2320, in start
#
#
#
#     success = self._bind_http_server()
#
#
#
#               ^^^^^^^^^^^^^^^^^^^^^^^^
#
#   File "/home/halil/.local/lib/python3.12/site-packages/notebook/notebookapp.py", line 1795, in _bind_http_server
#
#
#
#     return self._bind_http_server_unix() if self.sock else self._bind_http_server_tcp()
#
#
#
#                                                            ^^
#
# ^^^^^^^^^^^^^^^^^^^^^^^^^^
#
#   File "/home/halil/.local/lib/python3.12/site-packages/notebook/notebookapp.py", line 1821, in _bind_http_server_tcp
#
#
#
#     self.http_server.listen(port, self.ip)
#
#
#
#   File "/home/halil/.local/lib/python3.12/site-packages/tornado/tcpserver.py", line 191, in listen
#
#     self.add_sockets(sockets)
#
#
#
#   File "/home/halil/.local/lib/python3.12/site-packages/tornado/tcpserver.py", line 204, in add_sockets
#
#     self._handlers[sock.fileno()] = add_accept_handler(
#
#
#
#                               ^^^^^^^^^^^^^^^^^^^
#
#   File "/home/halil/.local/lib/python3.12/site-packages/tornado/netutil.py", line 247, in add_accept_handler
#
#
#
#     io_loop = IOLoop.current()
#
#               ^^^^^^^^^^^^^^^^
#
#   File "/home/halil/.local/lib/python3.12/site-packages/tornado/ioloop.py", line 265, in current
#
#     loop = asyncio.get_event_loop()
#
#            ^^^^
#
# ^^^^^^^^^^^^^^^^^^^^
#
#   File "/home/halil/.local/lib/python3.12/site-packages/nest_asyncio.py", line 45, in _get_event_loop
#
#     loop = events.get_event_loop_policy().get_event_loop()
#
#
#
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#
#   File "/usr/local/lib/python3.12/asyncio/events.py", line 676, in get_event_loop
#
#
#
#     raise RuntimeError('There is no current event loop in thread %r.'
#
# RuntimeError: There is no current event loop in thread 'MainThread'.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
numericalize(df,df["UsageBand"],"UsageBand")
# Out:
# Failed to start the Kernel.
#
# Jupyter server crashed. Unable to connect.
#
# Error code from Jupyter: 1
#
# /home/halil/.local/lib/python3.12/site-packages/traitlets/traitlets.py:2548: FutureWarning: Supporting extra quotes around strings is deprecated in traitlets 5.0. You can use '/home/halil/Belgeler/Kodlama calismalari/py/Patika/Intermadiate data science' instead of '"/home/halil/Belgeler/Kodlama calismalari/py/Patika/Intermadiate data science"' if you require traitlets >=5.
#
#   warn(
#
#
#
# [I 15:13:06.082 NotebookApp] Loading IPython parallel extension
#
#
#
# Traceback (most recent call last):
#
#   File "/home/halil/.local/bin/jupyter-notebook", line 8, in <module>
#
#
#
#     sys.exit(main())
#
#              ^^^^^^
#
#   File "/home/halil/.local/lib/python3.12/site-packages/jupyter_core/application.py", line 277, in launch_instance
#
#
#
#     return super().launch_instance(argv=argv, **kwargs)
#
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#
# ^^
#
#   File "/home/halil/.local/lib/python3.12/site-packages/traitlets/config/application.py", line 1043, in launch_instance
#
#
#
#     app.start()
#
#   File "/home/halil/.local/lib/python3.12/site-packages/notebook/notebookapp.py", line 2320, in start
#
#
#
#     success = self._bind_http_server()
#
#
#
#               ^^^^^^^^^^^^^^^^^^^^^^^^
#
#   File "/home/halil/.local/lib/python3.12/site-packages/notebook/notebookapp.py", line 1795, in _bind_http_server
#
#
#
#     return self._bind_http_server_unix() if self.sock else self._bind_http_server_tcp()
#
#
#
#                                                            ^^
#
# ^^^^^^^^^^^^^^^^^^^^^^^^^^
#
#   File "/home/halil/.local/lib/python3.12/site-packages/notebook/notebookapp.py", line 1821, in _bind_http_server_tcp
#
#
#
#     self.http_server.listen(port, self.ip)
#
#
#
#   File "/home/halil/.local/lib/python3.12/site-packages/tornado/tcpserver.py", line 191, in listen
#
#     self.add_sockets(sockets)
#
#
#
#   File "/home/halil/.local/lib/python3.12/site-packages/tornado/tcpserver.py", line 204, in add_sockets
#
#     self._handlers[sock.fileno()] = add_accept_handler(
#
#
#
#                               ^^^^^^^^^^^^^^^^^^^
#
#   File "/home/halil/.local/lib/python3.12/site-packages/tornado/netutil.py", line 247, in add_accept_handler
#
#
#
#     io_loop = IOLoop.current()
#
#               ^^^^^^^^^^^^^^^^
#
#   File "/home/halil/.local/lib/python3.12/site-packages/tornado/ioloop.py", line 265, in current
#
#     loop = asyncio.get_event_loop()
#
#            ^^^^
#
# ^^^^^^^^^^^^^^^^^^^^
#
#   File "/home/halil/.local/lib/python3.12/site-packages/nest_asyncio.py", line 45, in _get_event_loop
#
#     loop = events.get_event_loop_policy().get_event_loop()
#
#
#
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#
#   File "/usr/local/lib/python3.12/asyncio/events.py", line 676, in get_event_loop
#
#
#
#     raise RuntimeError('There is no current event loop in thread %r.'
#
# RuntimeError: There is no current event loop in thread 'MainThread'.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
df["UsageBand"]
# Out:
# Failed to start the Kernel.
#
# Jupyter server crashed. Unable to connect.
#
# Error code from Jupyter: 1
#
# /home/halil/.local/lib/python3.12/site-packages/traitlets/traitlets.py:2548: FutureWarning: Supporting extra quotes around strings is deprecated in traitlets 5.0. You can use '/home/halil/Belgeler/Kodlama calismalari/py/Patika/Intermadiate data science' instead of '"/home/halil/Belgeler/Kodlama calismalari/py/Patika/Intermadiate data science"' if you require traitlets >=5.
#
#   warn(
#
#
#
# [I 15:13:06.082 NotebookApp] Loading IPython parallel extension
#
#
#
# Traceback (most recent call last):
#
#   File "/home/halil/.local/bin/jupyter-notebook", line 8, in <module>
#
#
#
#     sys.exit(main())
#
#              ^^^^^^
#
#   File "/home/halil/.local/lib/python3.12/site-packages/jupyter_core/application.py", line 277, in launch_instance
#
#
#
#     return super().launch_instance(argv=argv, **kwargs)
#
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#
# ^^
#
#   File "/home/halil/.local/lib/python3.12/site-packages/traitlets/config/application.py", line 1043, in launch_instance
#
#
#
#     app.start()
#
#   File "/home/halil/.local/lib/python3.12/site-packages/notebook/notebookapp.py", line 2320, in start
#
#
#
#     success = self._bind_http_server()
#
#
#
#               ^^^^^^^^^^^^^^^^^^^^^^^^
#
#   File "/home/halil/.local/lib/python3.12/site-packages/notebook/notebookapp.py", line 1795, in _bind_http_server
#
#
#
#     return self._bind_http_server_unix() if self.sock else self._bind_http_server_tcp()
#
#
#
#                                                            ^^
#
# ^^^^^^^^^^^^^^^^^^^^^^^^^^
#
#   File "/home/halil/.local/lib/python3.12/site-packages/notebook/notebookapp.py", line 1821, in _bind_http_server_tcp
#
#
#
#     self.http_server.listen(port, self.ip)
#
#
#
#   File "/home/halil/.local/lib/python3.12/site-packages/tornado/tcpserver.py", line 191, in listen
#
#     self.add_sockets(sockets)
#
#
#
#   File "/home/halil/.local/lib/python3.12/site-packages/tornado/tcpserver.py", line 204, in add_sockets
#
#     self._handlers[sock.fileno()] = add_accept_handler(
#
#
#
#                               ^^^^^^^^^^^^^^^^^^^
#
#   File "/home/halil/.local/lib/python3.12/site-packages/tornado/netutil.py", line 247, in add_accept_handler
#
#
#
#     io_loop = IOLoop.current()
#
#               ^^^^^^^^^^^^^^^^
#
#   File "/home/halil/.local/lib/python3.12/site-packages/tornado/ioloop.py", line 265, in current
#
#     loop = asyncio.get_event_loop()
#
#            ^^^^
#
# ^^^^^^^^^^^^^^^^^^^^
#
#   File "/home/halil/.local/lib/python3.12/site-packages/nest_asyncio.py", line 45, in _get_event_loop
#
#     loop = events.get_event_loop_policy().get_event_loop()
#
#
#
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#
#   File "/usr/local/lib/python3.12/asyncio/events.py", line 676, in get_event_loop
#
#
#
#     raise RuntimeError('There is no current event loop in thread %r.'
#
# RuntimeError: There is no current event loop in thread 'MainThread'.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %% [markdown]
# ## Datatime Column

# %%
df["saledate"]
# Out:
# Failed to start the Kernel.
#
# Jupyter server crashed. Unable to connect.
#
# Error code from Jupyter: 1
#
# /home/halil/.local/lib/python3.12/site-packages/traitlets/traitlets.py:2548: FutureWarning: Supporting extra quotes around strings is deprecated in traitlets 5.0. You can use '/home/halil/Belgeler/Kodlama calismalari/py/Patika/Intermadiate data science' instead of '"/home/halil/Belgeler/Kodlama calismalari/py/Patika/Intermadiate data science"' if you require traitlets >=5.
#
#   warn(
#
#
#
# [I 15:13:06.082 NotebookApp] Loading IPython parallel extension
#
#
#
# Traceback (most recent call last):
#
#   File "/home/halil/.local/bin/jupyter-notebook", line 8, in <module>
#
#
#
#     sys.exit(main())
#
#              ^^^^^^
#
#   File "/home/halil/.local/lib/python3.12/site-packages/jupyter_core/application.py", line 277, in launch_instance
#
#
#
#     return super().launch_instance(argv=argv, **kwargs)
#
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#
# ^^
#
#   File "/home/halil/.local/lib/python3.12/site-packages/traitlets/config/application.py", line 1043, in launch_instance
#
#
#
#     app.start()
#
#   File "/home/halil/.local/lib/python3.12/site-packages/notebook/notebookapp.py", line 2320, in start
#
#
#
#     success = self._bind_http_server()
#
#
#
#               ^^^^^^^^^^^^^^^^^^^^^^^^
#
#   File "/home/halil/.local/lib/python3.12/site-packages/notebook/notebookapp.py", line 1795, in _bind_http_server
#
#
#
#     return self._bind_http_server_unix() if self.sock else self._bind_http_server_tcp()
#
#
#
#                                                            ^^
#
# ^^^^^^^^^^^^^^^^^^^^^^^^^^
#
#   File "/home/halil/.local/lib/python3.12/site-packages/notebook/notebookapp.py", line 1821, in _bind_http_server_tcp
#
#
#
#     self.http_server.listen(port, self.ip)
#
#
#
#   File "/home/halil/.local/lib/python3.12/site-packages/tornado/tcpserver.py", line 191, in listen
#
#     self.add_sockets(sockets)
#
#
#
#   File "/home/halil/.local/lib/python3.12/site-packages/tornado/tcpserver.py", line 204, in add_sockets
#
#     self._handlers[sock.fileno()] = add_accept_handler(
#
#
#
#                               ^^^^^^^^^^^^^^^^^^^
#
#   File "/home/halil/.local/lib/python3.12/site-packages/tornado/netutil.py", line 247, in add_accept_handler
#
#
#
#     io_loop = IOLoop.current()
#
#               ^^^^^^^^^^^^^^^^
#
#   File "/home/halil/.local/lib/python3.12/site-packages/tornado/ioloop.py", line 265, in current
#
#     loop = asyncio.get_event_loop()
#
#            ^^^^
#
# ^^^^^^^^^^^^^^^^^^^^
#
#   File "/home/halil/.local/lib/python3.12/site-packages/nest_asyncio.py", line 45, in _get_event_loop
#
#     loop = events.get_event_loop_policy().get_event_loop()
#
#
#
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#
#   File "/usr/local/lib/python3.12/asyncio/events.py", line 676, in get_event_loop
#
#
#
#     raise RuntimeError('There is no current event loop in thread %r.'
#
# RuntimeError: There is no current event loop in thread 'MainThread'.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
df["saledate"].year
# Out:
# Failed to start the Kernel.
#
# Jupyter server crashed. Unable to connect.
#
# Error code from Jupyter: 1
#
# /home/halil/.local/lib/python3.12/site-packages/traitlets/traitlets.py:2548: FutureWarning: Supporting extra quotes around strings is deprecated in traitlets 5.0. You can use '/home/halil/Belgeler/Kodlama calismalari/py/Patika/Intermadiate data science' instead of '"/home/halil/Belgeler/Kodlama calismalari/py/Patika/Intermadiate data science"' if you require traitlets >=5.
#
#   warn(
#
#
#
# [I 15:13:06.082 NotebookApp] Loading IPython parallel extension
#
#
#
# Traceback (most recent call last):
#
#   File "/home/halil/.local/bin/jupyter-notebook", line 8, in <module>
#
#
#
#     sys.exit(main())
#
#              ^^^^^^
#
#   File "/home/halil/.local/lib/python3.12/site-packages/jupyter_core/application.py", line 277, in launch_instance
#
#
#
#     return super().launch_instance(argv=argv, **kwargs)
#
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#
# ^^
#
#   File "/home/halil/.local/lib/python3.12/site-packages/traitlets/config/application.py", line 1043, in launch_instance
#
#
#
#     app.start()
#
#   File "/home/halil/.local/lib/python3.12/site-packages/notebook/notebookapp.py", line 2320, in start
#
#
#
#     success = self._bind_http_server()
#
#
#
#               ^^^^^^^^^^^^^^^^^^^^^^^^
#
#   File "/home/halil/.local/lib/python3.12/site-packages/notebook/notebookapp.py", line 1795, in _bind_http_server
#
#
#
#     return self._bind_http_server_unix() if self.sock else self._bind_http_server_tcp()
#
#
#
#                                                            ^^
#
# ^^^^^^^^^^^^^^^^^^^^^^^^^^
#
#   File "/home/halil/.local/lib/python3.12/site-packages/notebook/notebookapp.py", line 1821, in _bind_http_server_tcp
#
#
#
#     self.http_server.listen(port, self.ip)
#
#
#
#   File "/home/halil/.local/lib/python3.12/site-packages/tornado/tcpserver.py", line 191, in listen
#
#     self.add_sockets(sockets)
#
#
#
#   File "/home/halil/.local/lib/python3.12/site-packages/tornado/tcpserver.py", line 204, in add_sockets
#
#     self._handlers[sock.fileno()] = add_accept_handler(
#
#
#
#                               ^^^^^^^^^^^^^^^^^^^
#
#   File "/home/halil/.local/lib/python3.12/site-packages/tornado/netutil.py", line 247, in add_accept_handler
#
#
#
#     io_loop = IOLoop.current()
#
#               ^^^^^^^^^^^^^^^^
#
#   File "/home/halil/.local/lib/python3.12/site-packages/tornado/ioloop.py", line 265, in current
#
#     loop = asyncio.get_event_loop()
#
#            ^^^^
#
# ^^^^^^^^^^^^^^^^^^^^
#
#   File "/home/halil/.local/lib/python3.12/site-packages/nest_asyncio.py", line 45, in _get_event_loop
#
#     loop = events.get_event_loop_policy().get_event_loop()
#
#
#
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#
#   File "/usr/local/lib/python3.12/asyncio/events.py", line 676, in get_event_loop
#
#
#
#     raise RuntimeError('There is no current event loop in thread %r.'
#
# RuntimeError: There is no current event loop in thread 'MainThread'.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
df["saledate"].dt.year
# Out:
# Failed to start the Kernel.
#
# Jupyter server crashed. Unable to connect.
#
# Error code from Jupyter: 1
#
# /home/halil/.local/lib/python3.12/site-packages/traitlets/traitlets.py:2548: FutureWarning: Supporting extra quotes around strings is deprecated in traitlets 5.0. You can use '/home/halil/Belgeler/Kodlama calismalari/py/Patika/Intermadiate data science' instead of '"/home/halil/Belgeler/Kodlama calismalari/py/Patika/Intermadiate data science"' if you require traitlets >=5.
#
#   warn(
#
#
#
# [I 15:13:06.082 NotebookApp] Loading IPython parallel extension
#
#
#
# Traceback (most recent call last):
#
#   File "/home/halil/.local/bin/jupyter-notebook", line 8, in <module>
#
#
#
#     sys.exit(main())
#
#              ^^^^^^
#
#   File "/home/halil/.local/lib/python3.12/site-packages/jupyter_core/application.py", line 277, in launch_instance
#
#
#
#     return super().launch_instance(argv=argv, **kwargs)
#
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#
# ^^
#
#   File "/home/halil/.local/lib/python3.12/site-packages/traitlets/config/application.py", line 1043, in launch_instance
#
#
#
#     app.start()
#
#   File "/home/halil/.local/lib/python3.12/site-packages/notebook/notebookapp.py", line 2320, in start
#
#
#
#     success = self._bind_http_server()
#
#
#
#               ^^^^^^^^^^^^^^^^^^^^^^^^
#
#   File "/home/halil/.local/lib/python3.12/site-packages/notebook/notebookapp.py", line 1795, in _bind_http_server
#
#
#
#     return self._bind_http_server_unix() if self.sock else self._bind_http_server_tcp()
#
#
#
#                                                            ^^
#
# ^^^^^^^^^^^^^^^^^^^^^^^^^^
#
#   File "/home/halil/.local/lib/python3.12/site-packages/notebook/notebookapp.py", line 1821, in _bind_http_server_tcp
#
#
#
#     self.http_server.listen(port, self.ip)
#
#
#
#   File "/home/halil/.local/lib/python3.12/site-packages/tornado/tcpserver.py", line 191, in listen
#
#     self.add_sockets(sockets)
#
#
#
#   File "/home/halil/.local/lib/python3.12/site-packages/tornado/tcpserver.py", line 204, in add_sockets
#
#     self._handlers[sock.fileno()] = add_accept_handler(
#
#
#
#                               ^^^^^^^^^^^^^^^^^^^
#
#   File "/home/halil/.local/lib/python3.12/site-packages/tornado/netutil.py", line 247, in add_accept_handler
#
#
#
#     io_loop = IOLoop.current()
#
#               ^^^^^^^^^^^^^^^^
#
#   File "/home/halil/.local/lib/python3.12/site-packages/tornado/ioloop.py", line 265, in current
#
#     loop = asyncio.get_event_loop()
#
#            ^^^^
#
# ^^^^^^^^^^^^^^^^^^^^
#
#   File "/home/halil/.local/lib/python3.12/site-packages/nest_asyncio.py", line 45, in _get_event_loop
#
#     loop = events.get_event_loop_policy().get_event_loop()
#
#
#
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#
#   File "/usr/local/lib/python3.12/asyncio/events.py", line 676, in get_event_loop
#
#
#
#     raise RuntimeError('There is no current event loop in thread %r.'
#
# RuntimeError: There is no current event loop in thread 'MainThread'.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
"hey".capitalize()
# Out:
# Failed to start the Kernel.
#
# Jupyter server crashed. Unable to connect.
#
# Error code from Jupyter: 1
#
# /home/halil/.local/lib/python3.12/site-packages/traitlets/traitlets.py:2548: FutureWarning: Supporting extra quotes around strings is deprecated in traitlets 5.0. You can use '/home/halil/Belgeler/Kodlama calismalari/py/Patika/Intermadiate data science' instead of '"/home/halil/Belgeler/Kodlama calismalari/py/Patika/Intermadiate data science"' if you require traitlets >=5.
#
#   warn(
#
#
#
# [I 15:13:06.082 NotebookApp] Loading IPython parallel extension
#
#
#
# Traceback (most recent call last):
#
#   File "/home/halil/.local/bin/jupyter-notebook", line 8, in <module>
#
#
#
#     sys.exit(main())
#
#              ^^^^^^
#
#   File "/home/halil/.local/lib/python3.12/site-packages/jupyter_core/application.py", line 277, in launch_instance
#
#
#
#     return super().launch_instance(argv=argv, **kwargs)
#
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#
# ^^
#
#   File "/home/halil/.local/lib/python3.12/site-packages/traitlets/config/application.py", line 1043, in launch_instance
#
#
#
#     app.start()
#
#   File "/home/halil/.local/lib/python3.12/site-packages/notebook/notebookapp.py", line 2320, in start
#
#
#
#     success = self._bind_http_server()
#
#
#
#               ^^^^^^^^^^^^^^^^^^^^^^^^
#
#   File "/home/halil/.local/lib/python3.12/site-packages/notebook/notebookapp.py", line 1795, in _bind_http_server
#
#
#
#     return self._bind_http_server_unix() if self.sock else self._bind_http_server_tcp()
#
#
#
#                                                            ^^
#
# ^^^^^^^^^^^^^^^^^^^^^^^^^^
#
#   File "/home/halil/.local/lib/python3.12/site-packages/notebook/notebookapp.py", line 1821, in _bind_http_server_tcp
#
#
#
#     self.http_server.listen(port, self.ip)
#
#
#
#   File "/home/halil/.local/lib/python3.12/site-packages/tornado/tcpserver.py", line 191, in listen
#
#     self.add_sockets(sockets)
#
#
#
#   File "/home/halil/.local/lib/python3.12/site-packages/tornado/tcpserver.py", line 204, in add_sockets
#
#     self._handlers[sock.fileno()] = add_accept_handler(
#
#
#
#                               ^^^^^^^^^^^^^^^^^^^
#
#   File "/home/halil/.local/lib/python3.12/site-packages/tornado/netutil.py", line 247, in add_accept_handler
#
#
#
#     io_loop = IOLoop.current()
#
#               ^^^^^^^^^^^^^^^^
#
#   File "/home/halil/.local/lib/python3.12/site-packages/tornado/ioloop.py", line 265, in current
#
#     loop = asyncio.get_event_loop()
#
#            ^^^^
#
# ^^^^^^^^^^^^^^^^^^^^
#
#   File "/home/halil/.local/lib/python3.12/site-packages/nest_asyncio.py", line 45, in _get_event_loop
#
#     loop = events.get_event_loop_policy().get_event_loop()
#
#
#
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#
#   File "/usr/local/lib/python3.12/asyncio/events.py", line 676, in get_event_loop
#
#
#
#     raise RuntimeError('There is no current event loop in thread %r.'
#
# RuntimeError: There is no current event loop in thread 'MainThread'.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
# Out:
# Failed to start the Kernel.
#
# Jupyter server crashed. Unable to connect.
#
# Error code from Jupyter: 1
#
# /home/halil/.local/lib/python3.12/site-packages/traitlets/traitlets.py:2548: FutureWarning: Supporting extra quotes around strings is deprecated in traitlets 5.0. You can use '/home/halil/Belgeler/Kodlama calismalari/py/Patika/Intermadiate data science' instead of '"/home/halil/Belgeler/Kodlama calismalari/py/Patika/Intermadiate data science"' if you require traitlets >=5.
#
#   warn(
#
#
#
# [I 15:13:06.082 NotebookApp] Loading IPython parallel extension
#
#
#
# Traceback (most recent call last):
#
#   File "/home/halil/.local/bin/jupyter-notebook", line 8, in <module>
#
#
#
#     sys.exit(main())
#
#              ^^^^^^
#
#   File "/home/halil/.local/lib/python3.12/site-packages/jupyter_core/application.py", line 277, in launch_instance
#
#
#
#     return super().launch_instance(argv=argv, **kwargs)
#
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#
# ^^
#
#   File "/home/halil/.local/lib/python3.12/site-packages/traitlets/config/application.py", line 1043, in launch_instance
#
#
#
#     app.start()
#
#   File "/home/halil/.local/lib/python3.12/site-packages/notebook/notebookapp.py", line 2320, in start
#
#
#
#     success = self._bind_http_server()
#
#
#
#               ^^^^^^^^^^^^^^^^^^^^^^^^
#
#   File "/home/halil/.local/lib/python3.12/site-packages/notebook/notebookapp.py", line 1795, in _bind_http_server
#
#
#
#     return self._bind_http_server_unix() if self.sock else self._bind_http_server_tcp()
#
#
#
#                                                            ^^
#
# ^^^^^^^^^^^^^^^^^^^^^^^^^^
#
#   File "/home/halil/.local/lib/python3.12/site-packages/notebook/notebookapp.py", line 1821, in _bind_http_server_tcp
#
#
#
#     self.http_server.listen(port, self.ip)
#
#
#
#   File "/home/halil/.local/lib/python3.12/site-packages/tornado/tcpserver.py", line 191, in listen
#
#     self.add_sockets(sockets)
#
#
#
#   File "/home/halil/.local/lib/python3.12/site-packages/tornado/tcpserver.py", line 204, in add_sockets
#
#     self._handlers[sock.fileno()] = add_accept_handler(
#
#
#
#                               ^^^^^^^^^^^^^^^^^^^
#
#   File "/home/halil/.local/lib/python3.12/site-packages/tornado/netutil.py", line 247, in add_accept_handler
#
#
#
#     io_loop = IOLoop.current()
#
#               ^^^^^^^^^^^^^^^^
#
#   File "/home/halil/.local/lib/python3.12/site-packages/tornado/ioloop.py", line 265, in current
#
#     loop = asyncio.get_event_loop()
#
#            ^^^^
#
# ^^^^^^^^^^^^^^^^^^^^
#
#   File "/home/halil/.local/lib/python3.12/site-packages/nest_asyncio.py", line 45, in _get_event_loop
#
#     loop = events.get_event_loop_policy().get_event_loop()
#
#
#
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#
#   File "/usr/local/lib/python3.12/asyncio/events.py", line 676, in get_event_loop
#
#
#
#     raise RuntimeError('There is no current event loop in thread %r.'
#
# RuntimeError: There is no current event loop in thread 'MainThread'.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
